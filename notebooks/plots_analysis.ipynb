# %% [markdown]
# # By mechanism
# <img src="./plots/by_mechanism/f1.png" alt="description" width="400">
#
# - The correct directions are recovered more easily in datasets with solely linear mechanisms. The hardest dataset to recover the direction and the skeleton is the solely binary dataset. Include in the main body. OK
#
# <img src="./plots/by_mechanism/skeleton_f1.png" alt="description" width="400">
#
# - It is easier across all mechanisms to discover skeletons than directions. Sigmoid is easier to recover structure than Linear. Include in the main body. OK
#
# <img src="./plots/by_mechanism/precision.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix.
#
# <img src="./plots/by_mechanism/skeleton_precision.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix.
#
# <img src="./plots/by_mechanism/recall.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix.
#
# <img src="./plots/by_mechanism/skeleton_recall.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix.
#
# <img src="./plots/by_mechanism/median_frequency.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix. We will see this from the perspective of the algorithm.
#
# <img src="./plots/by_mechanism/ECE.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix. We will see this from the perspective of the algorithm.
#
# <img src="./plots/by_mechanism/SHD.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix. We will see this from the perspective of the algorithm.
#
# <img src="./plots/by_mechanism/Skeleton SHD.png" alt="description" width="400">
#
# - Not to include in the main body nor in the appendix. We will see this from the perspective of the algorithm.
#
# <img src="./plots/by_mechanism/training_time.png" alt="description" width="400">
#
# - Strange that the time varies so much. Maybe this is due to the heterogeneus computing power in Fraunhofer's cluster. Not to include in the main body nor in the appendix. We will see this from the perspective of the algorithm.

# %% [markdown]
# # By algorithm
# <img src="./plots/by_algorithm/f1.png" alt="description" width="400">
#
# -  Performance of recovering the skeleton is $25$ p.p. higher than performance of recovering the directions. FGES, BOSS and GRaSP show similar performance, which is higher than PC.
#
# <img src="./plots/by_algorithm/skeleton_f1.png" alt="description" width="400">
#
# -  Performance of recovering the skeleton is $25$ p.p. higher than performance of recovering the directions. FGES, BOSS and GRaSP show similar performance, which is higher than PC.
#
# <img src="./plots/by_algorithm/precision.png" alt="description" width="400">
#
# - PC showed lower F1, but has high precision, along with GRaSP. Not to show in main body. Show in appendix. NOK
#
# <img src="./plots/by_algorithm/skeleton_precision.png" alt="description" width="400">
#
# - PC showed lower F1, but has high skeleton precision, along with GRaSP. Not to show in main body. Show in appendix. NOK
#
# <img src="./plots/by_algorithm/recall.png" alt="description" width="400">
#
# - PC shows lower recall than the other algorithms. Not to show in main body. Show in appendix. NOK
#
# <img src="./plots/by_algorithm/skeleton_recall.png" alt="description" width="400">
#
# - PC shows lower skeleton recall than the other algorithms. Not to show in main body. Show in appendix. NOK
#
# <img src="./plots/by_algorithm/median_frequency.png" alt="description" width="400">
#
# - All algorithms have very stable output across bootstrap samples. Show in main body. OK
#
# <img src="./plots/by_algorithm/ECE.png" alt="description" width="400">
#
# - BOSS and FGES show higher ECE. Show in main body. OK
#
# <img src="./plots/by_algorithm/SHD.png" alt="description" width="400">
#
# - Does not make sense to analyse without controlling for number of nodes.
#
# <img src="./plots/by_algorithm/Skeleton SHD.png" alt="description" width="400">
#
# - Does not make sense to analyse without controlling for number of nodes.
#
# <img src="./plots/by_algorithm/training_time.png" alt="description" width="400">
#
# - Very counterintuitive result, since BOSS and GRaSP papers report lower training time. Likely due to heterogeneus compute used.

# %% [markdown]
# # By algorithm and number of nodes
# <img src="./plots/by_algorithm_nodes/f1.png" alt="description" width="800">
#
# - Surprising that BOSS, FGES, GRaSP show increase in F1 with higher number of nodes. PC shows decline. **Why?**. Show in main body. OK
#
# <img src="./plots/by_algorithm_nodes/skeleton_f1.png" alt="description" width="800">
#
# - As expected, performance of skeleton recovery declines with the increase in number of nodes. Across all algorithms. Show in main body. OK
#
# <img src="./plots/by_algorithm_nodes/precision.png" alt="description" width="800">
#
# - There is a drop in precision from 5 to 10 nodes across algorithms. Significant drop for PC. Tests with 40 and 50 nodes have higher performance in BOSS, FGES and GRaSP. Show in main body. OK
#
# <img src="./plots/by_algorithm_nodes/skeleton_precision.png" alt="description" width="800">
#
# - Follows behaviour of precision. Precision of 1 in graphs with 5 nodes for all algorithms is surprising. OK
#
# <img src="./plots/by_algorithm_nodes/recall.png" alt="description" width="800">
#
# - Recall incresases significantly for BOSS, FGES and GRaSP, while decreases for PC. This is likely the main cause for the difference in f1 between the algorithms. BOSS, FGES and GRaSP are score based, while PC is independence based. Add to main body. OK
#
# <img src="./plots/by_algorithm_nodes/skeleton_recall.png" alt="description" width="800">
#
# - Already analysed recall. OK
#
# <img src="./plots/by_algorithm_nodes/median_frequency.png" alt="description" width="800">
#
# - Already analysed
#
# <img src="./plots/by_algorithm_nodes/ECE.png" alt="description" width="800">
#
# - Already analysed
#
# <img src="./plots/by_algorithm_nodes/SHD.png" alt="description" width="800">
#
# - Already analysed. OK
#
# <img src="./plots/by_algorithm_nodes/Skeleton SHD.png" alt="description" width="800">
#
# - Already analysed. OK
#
# <img src="./plots/by_algorithm_nodes/training_time.png" alt="description" width="800">
#
# - Shows how training time increases expontentially. I don't trust these results due to heterogenous computing resources in the cluster. Add in appendix. NOK

# %% [markdown]
# # By algorithm and number of tiers
# <img src="./plots/by_algorithm_tiers/f1.png" alt="description" width="800">
#
# - The recovery of direction improves significantly with the addition of domain knowledge, with and average increase of $27$ p.p. between $1$ and $5$ tiers, across algorithms. OK
#
# <img src="./plots/by_algorithm_tiers/skeleton_f1.png" alt="description" width="800">
#
# - The recovery of structure does not improve with the addition of domain knowledge. OK
#
# <img src="./plots/by_algorithm_tiers/precision.png" alt="description" width="800">
#
# - Recovery of direction becomes more precise. Show in appendix. NOK
#
# <img src="./plots/by_algorithm_tiers/skeleton_precision.png" alt="description" width="800">
#
# - No new insights
#
# <img src="./plots/by_algorithm_tiers/recall.png" alt="description" width="800">
#
# - Recall improves as well. Show in appendix. NOK
#
# <img src="./plots/by_algorithm_tiers/skeleton_recall.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_tiers/median_frequency.png" alt="description" width="800">
#
# - No new insights
#
# <img src="./plots/by_algorithm_tiers/ECE.png" alt="description" width="800">
#
# - No new insights
#
# <img src="./plots/by_algorithm_tiers/SHD.png" alt="description" width="800">
#
# - Why does the SHD does not improve with an increase of domain knowledge??
#
# <img src="./plots/by_algorithm_tiers/Skeleton SHD.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_tiers/training_time.png" alt="description" width="800">
#
# - Weird perspective for this metric. But i expected more evenly distributed times

# %% [markdown]
# # By algorithm and mechanism type
# <img src="./plots/by_algorithm_mechanism/f1.png" alt="description" width="800">
#
# - PC's and FGES performance is evenly distributed across mechanisms. BOSS and GRaSP show peaks of performance in linear and Sigmoid mechanisms. Add to body. OK
#
# <img src="./plots/by_algorithm_mechanism/skeleton_f1.png" alt="description" width="800">
#
# - Similar insight as previous image.
#
# <img src="./plots/by_algorithm_mechanism/precision.png" alt="description" width="800">
#
# - Similar insight as previous image.
#
# <img src="./plots/by_algorithm_mechanism/skeleton_precision.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_mechanism/recall.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_mechanism/skeleton_recall.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_mechanism/median_frequency.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_mechanism/ECE.png" alt="description" width="800">
#
# - No new insights.
# -
# <img src="./plots/by_algorithm_mechanism/SHD.png" alt="description" width="800">
#
# - No new insights.
# -
# <img src="./plots/by_algorithm_mechanism/Skeleton SHD.png" alt="description" width="800">
#
# - No new insights.
#
# <img src="./plots/by_algorithm_mechanism/training_time.png" alt="description" width="800">
#
# - No new insights.
